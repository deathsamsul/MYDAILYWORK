# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-31e51066-cd58-478a-ae68-31f7df73731c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31e51066-cd58-478a-ae68-31f7df73731c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
# !pip install scikit-learn==1.8.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 81.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
df=pd.read_csv('Churn.csv')

# %%
df.sample(2)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5754  1431-CYWMH  Female              0     Yes        Yes      22
# 4679  8218-FFJDS  Female              0     Yes         No      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5754          Yes            No              No  No internet service  ...
# 4679          Yes           Yes             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5754  No internet service  No internet service  No internet service
# 4679                   No                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5754  No internet service  Month-to-month               No
# 4679                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 5754  Bank transfer (automatic)          19.05        454.05    No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
new_df=df.drop('customerID',axis=1)

# %%
new_df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
new_df['TotalCharges'].mode()[1]
# Out:
# '20.2'

# %%
new_df[new_df['TotalCharges']==' ']=new_df.replace(' ',new_df['TotalCharges'].mode()[1])

# %%
new_df[new_df['TotalCharges']==' ']
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
new_df['TotalCharges']=new_df['TotalCharges'].astype(float)

# %%
  new_df['avg_spend']=new_df['TotalCharges']/new_df['tenure'].replace(0,1)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
new_df.columns.tolist()
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn',
#  'avg_spend']

# %%
# creating average monthly sepender
def avg_spend(new_df:pd.DataFrame)->pd.DataFrame:
  new_df=new_df.copy()
  new_df['avg_spend']=new_df['TotalCharges']/new_df['tenure'].replace(0,1)
  return new_df

# %%
# from sklearn.preprocessing import FunctionTransformer
# feature_adder=FunctionTransformer(avg_spend,validate=False)

# %%
y=new_df['Churn']
new_df.drop('Churn',axis=1,inplace=True)

# %%
x=new_df

# %%
y.replace({"Yes":1,"No":0},inplace=True)
# Out:
# /tmp/ipython-input-802501325.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y.replace({"Yes":1,"No":0},inplace=True)

# %%
cat_cols=new_df.select_dtypes(include=['object']).columns.tolist()
num_cols=new_df.select_dtypes(exclude=['object']).columns.tolist()
# num_cols.append('avg_spend')

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
transformer=ColumnTransformer(transformers=[('scaler',StandardScaler(),num_cols),
                               ('encoder',OneHotEncoder(drop='first',handle_unknown='ignore'),cat_cols)])

# %%
from sklearn.model_selection import GridSearchCV

# %%
# xgb=XGBClassifier(tree_method='hist',device='cuda',subsample=1,colsample_bytree=1)

# %%
# pipe=Pipeline(steps=[
#     ('transformer',transformer),
#     ('model',xgb)
# ])

# %%
# params={
#     'model__max_depth':[3,4,5],
#     'model__n_estimators':[500,1000],
#     'model__learning_rate':[0.1,0.05,0.001],
#     'model__gamma':[0,0.1,0.2],
#     'model__min_child_weight':[1,3,5]
# }

# %%
# grid=GridSearchCV(pipe,param_grid=params,cv=5,verbose=0)

# %%
# grid.fit(x,y)

# %%
# print(grid.best_params_)
# print(grid.best_score_)
# {'model__gamma': 0, 'model__learning_rate': 0.05, 'model__max_depth': 3, 'model__min_child_weight': 1, 'model__n_estimators': 500}
# 0.8037780663268599

# %%
#catboostclassifier
#{'model__depth': 4, 'model__iterations': 1500, 'model__learning_rate': 0.1}
#0.8036363233111814

#xgbclassifier
#{'model__colsample_bytree': 1.0, 'model__gamma': 0, 'model__learning_rate': 0.05, 'model__max_depth': 3, 'model__min_child_weight': 1, 'model__n_estimators': 500, 'model__subsample': 1.0}
#0.8037780663268599

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
pipeline=Pipeline(steps=[
    ('transformer',transformer),
    ('clf_model',lr)
])

# %%
params={
    'clf_model__penalty':['l1','l2'],
    'clf_model__C':[0.01,0.1],
    'clf_model__solver':['liblinear','saga'],
    'clf_model__max_iter':[200,500]
}

# %%
#grid=GridSearchCV(pipeline,param_grid=params,cv=5,verbose=0)

# %%
#grid.fit(x_train,y_train)

# %%
lr_model=LogisticRegression(C=0.1,max_iter=200,penalty='l2',solver='liblinear')

# %%
pipeline=Pipeline(steps=[
    ('transformer',transformer),
    ('clf_model',lr_model)
])

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
pipeline.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'avg_spend']),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
# ...

# %%
y_pred=pipeline.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8097941802696949

# %%
import pickle

# %%
with open('model_v3.pkl','wb') as file:
  pickle.dump(pipeline,file)

# %%
from google import colab
colab.files.download('model_v3.pkl')
